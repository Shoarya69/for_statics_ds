# %%
import pandas as pd
import numpy as np
import scipy.stats as ss

# %%
df = pd.read_csv('cars_output.csv')
df
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1      07/03/2016 09:54                             Volvo_XC90_2.4D_Summum
# 2      01/04/2016 00:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 45594  09/03/2016 01:36                                        Porsche_993
# 45595  23/03/2016 21:45  Opel_Astra_G_Caravan__Tuev_2/2018__Scheckheft_...
# 45596  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 45597  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 45598  22/03/2016 09:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType   price   abtest    vehicleType  \
# ...

# %%
cars = df.copy()

# %%
cars = cars[
    (cars.yearOfRegistration <=2018) &
    (cars.yearOfRegistration >=1950) &
    (cars.price >= 100) &
    (cars.price <= 150000) &
    (cars.powerPS >= 10) &
    (cars.powerPS <=500)
]
cars
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1      07/03/2016 09:54                             Volvo_XC90_2.4D_Summum
# 2      01/04/2016 00:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 45591  10/03/2016 23:36                                        BMW_X3_3.0i
# 45592  14/03/2016 13:57                         Opel_Astra_2.0_DI_Elegance
# 45593  14/03/2016 11:37       Renault_Clio_mit_Servolenkung_und_neuem_TÜV!
# 45595  23/03/2016 21:45  Opel_Astra_G_Caravan__Tuev_2/2018__Scheckheft_...
# 45598  22/03/2016 09:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
sample_size = 1000
sample = cars.sample(sample_size,random_state=0)

# %%
cars_mean = 6000
print(sample['price'].mean())
# Out:
# 5791.228

# %%
stati,pvalue = ss.ttest_1samp(sample['price'],cars_mean)
print(stati,pvalue)
# Out:
# -0.9000743615546267 0.36829759156631026

# %%
n = len(cars['price'])

dof = n-1

print(n,dof)
# Out:
# 41115 41114

# %%
alpha = 0.05

# %%
cv = ss.t.ppf([alpha/2,1-alpha/2],dof)
print(cv)
# Out:
# [-1.96002169  1.96002169]

# %%
if alpha <= pvalue:
    print('i accepte my null hypothoses')
else:
    print('Reject my null hypothes')
# Out:
# i accepte my null hypothoses
